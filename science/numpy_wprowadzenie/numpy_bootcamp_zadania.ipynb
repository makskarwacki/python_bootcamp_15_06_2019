# %% [markdown]
# Napisz poniżej funkcję, która wyprintuje Twoje imię i nazwisko:

# %% [markdown]
# # Indeksowanie, wycinanie, iterowanie - Indexing, Slicing and Iterating

# %% [markdown]
# ### Stwórz liste sześcianów liczb od 0 do 9

# %% [markdown]
# ### wybierz z listy zaznaczone elementy
#
# [ 0, 1, **8**, **27**, **64**, 125, 216, 343, 512, 729]

# %% [markdown]
# [ **0**, 1, **8**, 27, **64**, 125, 216, 343, 512, 729]

# %% [markdown]
# ### przekształć by otrzymać wynik
#
# [-1000, 1,  -1000, 27, -1000,   125,   216,   343,   512, 729]

# %% [markdown]
# ### Odwróć listę

# %% [markdown]
# ### Sprawdź typ

# %% [markdown]
# ### W pętli for wyprintuj dla każdego elementu pierwiastek sześcienny z elementy

# %% [markdown]
# ### Stwórz macierz 10x10 z kwadratami liczb od 1 do 100

# %% [markdown]
# ### Stwórz macierz 5x5 gdzie na krawędziach będą 0 a w środku 1

# %% [markdown]
# ### Stwórz tabliczkę mnożenia liczb od 0 do 9 w postaci dwuwymiarowej macierzy

# %%
# !ls
# Out:
# bmp.py
# ex_1.py
# ex_2.py
# images
# intro_numpy.ipynb
# Podstawy Pythona 04 - Exceptions - 03.12.2016.ipynb
# Podstawy Pythona 04 - NumPy Basics - 03.12.2016.ipynb
# Untitled.ipynb

# %% [markdown]
# ## Zad 2  Przekształć wczytane obrazki w opisany sposób

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/99/ad/864b2f284517249a96190fdf6b21a291d9716115d6886938ccd86afaf821/opencv_python-4.1.0.25-cp37-cp37m-win32.whl (25.7MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages (from opencv-python) (1.17.0)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.1.0.25
# You are using pip version 19.0.3, however version 19.2.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import matplotlib.image as mpimg
im1 = mpimg.imread('images/monkey.png')
im1
# Out:
# array([[[0.6862745 , 0.7764706 , 0.69803923, 1.        ],
#         [0.6862745 , 0.7764706 , 0.69803923, 1.        ],
#         [0.6862745 , 0.78039217, 0.69411767, 1.        ],
#         ...,
#         [0.7764706 , 0.7058824 , 0.5254902 , 1.        ],
#         [0.7764706 , 0.7058824 , 0.5254902 , 1.        ],
#         [0.7764706 , 0.7058824 , 0.5254902 , 1.        ]],
#
#        [[0.6862745 , 0.7764706 , 0.69803923, 1.        ],
#         [0.6862745 , 0.78039217, 0.69411767, 1.        ],
#         [0.6862745 , 0.78039217, 0.69411767, 1.        ],
#         ...,
#         [0.7764706 , 0.7058824 , 0.5254902 , 1.        ],
#         [0.7764706 , 0.7058824 , 0.5254902 , 1.        ],
#         [0.7764706 , 0.7058824 , 0.5254902 , 1.        ]],
#
#        [[0.6901961 , 0.7764706 , 0.69411767, 1.        ],
#         [0.6901961 , 0.7764706 , 0.69411767, 1.        ],
#         [0.6901961 , 0.7764706 , 0.69411767, 1.        ],
#         ...,
#         [0.7764706 , 0.7058824 , 0.5254902 , 1.        ],
#         [0.7764706 , 0.7058824 , 0.5254902 , 1.        ],
#         [0.7764706 , 0.7058824 , 0.5254902 , 1.        ]],
#
#        ...,
#
#        [[0.7411765 , 0.70980394, 0.42745098, 1.        ],
#         [0.7411765 , 0.70980394, 0.42745098, 1.        ],
#         [0.74509805, 0.7137255 , 0.43137255, 1.        ],
#         ...,
#         [0.60784316, 0.64705884, 0.30980393, 1.        ],
#         [0.61960787, 0.6431373 , 0.30588236, 1.        ],
#         [0.62352943, 0.64705884, 0.3019608 , 1.        ]],
#
#        [[0.74509805, 0.7137255 , 0.42745098, 1.        ],
#         [0.74509805, 0.7137255 , 0.42745098, 1.        ],
#         [0.74509805, 0.7137255 , 0.42745098, 1.        ],
#         ...,
#         [0.60784316, 0.64705884, 0.30980393, 1.        ],
#         [0.6117647 , 0.6431373 , 0.30588236, 1.        ],
#         [0.6117647 , 0.64705884, 0.29803923, 1.        ]],
#
#        [[0.75686276, 0.7254902 , 0.43137255, 1.        ],
#         [0.75686276, 0.7254902 , 0.43137255, 1.        ],
#         [0.75686276, 0.7254902 , 0.43137255, 1.        ],
#         ...,
#         [0.6156863 , 0.67058825, 0.3372549 , 1.        ],
#         [0.6156863 , 0.6627451 , 0.3254902 , 1.        ],
#         [0.61960787, 0.65882355, 0.31764707, 1.        ]]], dtype=float32)

# %%
import cv2
im2 = cv2.imread("images/index.jpeg")
im2
# Out:
# array([[[178, 198, 175],
#         [178, 198, 175],
#         [177, 199, 175],
#         ...,
#         [134, 180, 198],
#         [134, 180, 198],
#         [134, 180, 198]],
#
#        [[178, 198, 175],
#         [177, 199, 175],
#         [177, 199, 175],
#         ...,
#         [134, 180, 198],
#         [134, 180, 198],
#         [134, 180, 198]],
#
#        [[177, 198, 176],
#         [177, 198, 176],
#         [177, 198, 176],
#         ...,
#         [134, 180, 198],
#         [134, 180, 198],
#         [134, 180, 198]],
#
#        ...,
#
#        [[109, 181, 189],
#         [109, 181, 189],
#         [110, 182, 190],
#         ...,
#         [ 79, 165, 155],
#         [ 78, 164, 158],
#         [ 77, 165, 159]],
#
#        [[109, 182, 190],
#         [109, 182, 190],
#         [109, 182, 190],
#         ...,
#         [ 79, 165, 155],
#         [ 78, 164, 156],
#         [ 76, 165, 156]],
#
#        [[110, 185, 193],
#         [110, 185, 193],
#         [110, 185, 193],
#         ...,
#         [ 86, 171, 157],
#         [ 83, 169, 157],
#         [ 81, 168, 158]]], dtype=uint8)

# %%
im1.shape
# Out:
# (177, 284, 4)

# %%
im2.shape
# Out:
# (177, 284, 3)

# %%
plt.imshow(im2)

# %%
plt.imshow(im2)

# %% [markdown]
# ### stwórz wycinek -  spróbuj wybrać twarz

# %%
plt.imshow(im1[25:160,90:180,])

# %% [markdown]
# ### wybierz jeden kolor

# %%
import numpy as np

# %%
RED = True
GREEN  = True
BLUE = False
ALPHA = 0.99
colors = np.array([RED, GREEN, BLUE, ALPHA])

plt.imshow(im1 * colors)

# %% [markdown]
# ### Obrót o wskazaną liczbę stopni
#
# wykorzystaj ndimage.rotate ze scipy

# %%
from scipy import ndimage

# %%
plt.imshow(ndimage.rotate(im1, 70))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Czarno biały filtr

# %%
X = np.arange(300).reshape(10, 10, 3)
Y = X.sum(axis=2, keepdims=True)
Y = Y/Y.max()
print(Y.shape)
plt.imshow(np.ones(3)*Y)
# Out:
# (10, 10, 1)

# %%
im2.shape
# Out:
# (177, 284, 3)

# %%
im3 = im2[:,:,:]
im3.shape
# Out:
# (177, 284, 3)

# %%
im3[:,:,1] = im3[:,:,0]
im3[:,:,2] = im3[:,:,0]

plt.imshow(im3)

# %%
im4 = im2[:,:,:]

# %%
sum_array = im4.sum(axis=2, keepdims=True)
sum_array = sum_array / sum_array.max()
plt.imshow(np.ones(3)*sum_array)

# %% [markdown]
# ### Rozmazanie

# %% [markdown]
# wykorzystaj `ndimage.gaussian_filter`

# %% [markdown]
# Wyślij mi to proszę na adres: korzeniewski@gmail.com, w tytule wpisz "Ćwiczenia z NumPy"

# %%
ndimage.gaussian_filter?

# %%
plt.imshow(ndimage.gaussian_filter(im1, 1))
